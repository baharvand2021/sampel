# %%
import pcse

# %%
wofost_object = pcse.start_wofost(grid=31031, crop=1, year=2000)
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\pcse\db\pcse\db_input.py:630: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   items = yaml.load(input)
# C:\Users\Administrator\Anaconda3\lib\site-packages\sqlalchemy\sql\sqltypes.py:665: SAWarning: Dialect sqlite+pysqlite does *not* support Decimal objects natively, and SQLAlchemy must convert from floating point - rounding errors and other issues may occur. Please consider storing Decimal numbers as strings or integers on this platform for lossless storage.
#   "storage." % (dialect.name, dialect.driver)

# %%
type(wofost_object)
# Out:
# pcse.models.Wofost71_WLP_FD

# %%
 wofost_object.run()

# %%
wofost_object.run(days=10)

# %%
wofost_object.get_variable('LAI')
# Out:
# 0.2870809817505803
